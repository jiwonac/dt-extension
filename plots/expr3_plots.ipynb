# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
labels = ['random', 'coupcoll-nodupe', 'ratiocoll-nodupe', 'epsilon-exact-nodupe', 'coupcoll-dupe', 'ratiocoll-dupe', 'epsilon-exact-dupe']
values = [14858764.0, 10155709.0, 7034418.0, 7074358.0]

# %%
plt.bar(labels, values, edgecolor=black, width=0.5, fill=False, hatch='////')
plt.xlabel('Algorithm')
plt.ylabel('Total Queries (10 million)')
# Out:
# Text(0, 0.5, 'Total Queries (10 million)')
